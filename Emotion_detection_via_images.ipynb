# %% [markdown]
# <a href="https://colab.research.google.com/github/Stehen76/Exercise/blob/main/Emotion_detection_via_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61kB 1.9MB/s
# ...
#      |████████████████████████████████| 2.3MB 5.7MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-3.12.2-cp36-none-any.whl size=9693 sha256=c3c7f108c3f5da82fa8835e4f0c48f2f97258f9865d07e3e33bfea84a9b375cd
#   Stored in directory: /root/.cache/pip/wheels/81/d0/d7/d9983facc6f2775411803e0e2d30ebf98efbf2fc6e57701e09
# Successfully built gdown
# ...
#   Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab import drive
drive.mount('\content\gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g65X4uHPCx4kSBQ1x4e2g3Fue6ZjCrogEjszTg59sxBlTBFGzRrxMU
# ---------------------------------------------------------------------------
# TIMEOUT                                   Traceback (most recent call last)
# <ipython-input-3-146ded77654b> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('\content\gdrive')
#
# ...

# %%
imgl =cv2.imread('/content/contentgdrive/MyDrive/lena.png')
plt.imshow(imgl[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(imgl, actions = ['emotion'])
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://drive.google.com/uc?id=13iUHHP3SlNg53qSuQZDdHDSDNdBP9nwy
# To: /root/.deepface/weights/facial_expression_model_weights.zip
# 5.54MB [00:00, 34.2MB/s]

# %%
print(result)
# Out:
# {'emotion': {'angry': 0.001070051803253591, 'disgust': 4.8583771554422395e-11, 'fear': 7.693556902665932e-07, 'happy': 89.55668210983276, 'sad': 0.0019165452613378875, 'surprise': 0.0002068686626444105, 'neutral': 10.440120100975037}, 'dominant_emotion': 'happy'}
